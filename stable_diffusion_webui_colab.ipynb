# %% [markdown]
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
# **It is necessary to change runtime type to GPU if not using "--skip-torch-cuda-test --no-half --use-cpu all"**
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %% [markdown]
# ![Screenshot 2023-04-08 at 9.29.45 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2023-04-08 at 9.31.57 PM.png](data:image/png;base64,...)

# %%
# !pip install --upgrade fastapi==0.90.0

# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui
# !git clone https://github.com/yfszzx/stable-diffusion-webui-images-browser /content/stable-diffusion-webui/extensions/stable-diffusion-webui-images-browser

# !curl -Lo MeinaPastelV3.safetensors https://huggingface.co/Meina/MeinaPastel/resolve/main/MeinaPastelV3%20-%20Without%20VAE.safetensors
# !mv "/content/MeinaPastelV3.safetensors" "/content/stable-diffusion-webui/models/Stable-diffusion"
# !curl -Lo Counterfeit-V2.5_pruned.safetensors https://huggingface.co/gsdf/Counterfeit-V2.5/resolve/main/Counterfeit-V2.5_pruned.safetensors
# !mv "/content/Counterfeit-V2.5_pruned.safetensors" "/content/stable-diffusion-webui/models/Stable-diffusion"
# !curl -Lo AbyssOrangeMix3A3.safetensors https://huggingface.co/sakistriker/AbyssOrangeMix3A3/resolve/main/AOM3A3.safetensors
# !mv "/content/AbyssOrangeMix3A3.safetensors" "/content/stable-diffusion-webui/models/Stable-diffusion"
# !curl -Lo cetusMix_Version35.safetensors https://huggingface.co/ckpt/cetus-mix/resolve/main/cetusMix_Version35.safetensors
# !mv "/content/cetusMix_Version35.safetensors" "/content/stable-diffusion-webui/models/Stable-diffusion"
# !curl -Lo Meina%20V8%20pruned.safetensors https://huggingface.co/Meina/MeinaMix/resolve/main/Meina%20V8%20pruned.safetensors
# !mv "/content/Meina%20V8%20pruned.safetensors" "/content/stable-diffusion-webui/models/Stable-diffusion"

# ControlNet
# !git clone https://github.com/Mikubill/sd-webui-controlnet /content/stable-diffusion-webui/extensions/sd-webui-controlnet
# Posex for ControlNet
# !git clone https://github.com/hnmr293/posex /content/stable-diffusion-webui/extensions/posex

# ControlNet Models
# V1.1
# !curl -Lo control_v11p_sd15_canny_fp16.safetensors https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_canny_fp16.safetensors
# !mv "/content/control_v11p_sd15_canny_fp16.safetensors" "/content/stable-diffusion-webui/extensions/sd-webui-controlnet/models"
# !curl -Lo control_v11f1p_sd15_depth_fp16.safetensors https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11f1p_sd15_depth_fp16.safetensors
# !mv "/content/control_v11f1p_sd15_depth_fp16.safetensors" "/content/stable-diffusion-webui/extensions/sd-webui-controlnet/models"
# !curl -Lo control_v11p_sd15_mlsd_fp16.safetensors https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_mlsd_fp16.safetensors
# !mv "/content/control_v11p_sd15_mlsd_fp16.safetensors" "/content/stable-diffusion-webui/extensions/sd-webui-controlnet/models"
# !curl -Lo control_v11p_sd15_normalbae_fp16.safetensors https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_normalbae_fp16.safetensors
# !mv "/content/control_v11p_sd15_normalbae_fp16.safetensors" "/content/stable-diffusion-webui/extensions/sd-webui-controlnet/models"
# !curl -Lo control_v11p_sd15_openpose_fp16.safetensors https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_openpose_fp16.safetensors
# !mv "/content/control_v11p_sd15_openpose_fp16.safetensors" "/content/stable-diffusion-webui/extensions/sd-webui-controlnet/models"
# !curl -Lo control_v11p_sd15_scribble_fp16.safetensors https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_scribble_fp16.safetensors
# !mv "/content/control_v11p_sd15_scribble_fp16.safetensors" "/content/stable-diffusion-webui/extensions/sd-webui-controlnet/models"
# !curl -Lo control_v11p_sd15_seg_fp16.safetensors https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_seg_fp16.safetensors
# !mv "/content/control_v11p_sd15_seg_fp16.safetensors" "/content/stable-diffusion-webui/extensions/sd-webui-controlnet/models"
# !curl -Lo control_v11p_sd15s2_lineart_anime_fp16.safetensors https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15s2_lineart_anime_fp16.safetensors
# !mv "/content/control_v11p_sd15s2_lineart_anime_fp16.safetensors" "/content/stable-diffusion-webui/extensions/sd-webui-controlnet/models"

# %cd /content/stable-diffusion-webui
# !git checkout 91c8d0d

# %%
# %pip install torch==1.13.1+cu117 torchvision==0.14.1+cu117 torchtext==0.14.1 torchaudio==0.13.1 torchdata==0.5.1 --extra-index-url https://download.pytorch.org/whl/cu117

# GPU required
# !COMMANDLINE_ARGS="--share --disable-safe-unpickle --no-half-vae --xformers --reinstall-xformers --enable-insecure-extension-access" REQS_FILE="requirements.txt" python launch.py
# No GPU required
# !COMMANDLINE_ARGS="--share --disable-safe-unpickle --skip-torch-cuda-test --no-half --use-cpu all --enable-insecure-extension-access" REQS_FILE="requirements.txt" python launch.py
